# %%
import scipy.stats as stats
% pylab inline
import matplotlib.pyplot as plt
import numpy as np
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ## Caminata Aleatoria

# %%
n_steps = 50 # numero de pasos
ks=[]
ps=[]
p=[]
walk_x = np.zeros(n_steps) 
for k in range (100): # Numero de repeticiones de las repeticiones del experimento de caminata aleatoria ya realizado
    ks.append(k)
    promedios=[]
    promediototal=0   
    for j in range (100): # Numero de repeticiones del experimento de caminata aleatoria
        promedio=0 
        for i in range(n_steps-1): #experimentos de n_steps pasos
            walk_x[i+1] = walk_x[i] + random.choice((-1,1))
            promedio=sum(walk_x)/n_steps
        promedios.append(promedio)
        promediototal+=promedio
    des=np.std(promedios) #Desviacion Standart de los promedios
    promediototal=float(promediototal)/100
    t=(abs(promediototal)-n_steps*0.5)/des #el valor medio de la distancia para una caminata aleatoria es n_steps*p
    p=stats.t.sf(np.abs(t), 1)*2 #p-value para el problema de caminata aleatoria
    ps.append(p)


scatter(ks,ps)

# %%
n_steps = 100 # numero de pasos
ks=[]
ps=[]
p=[]
walk_x = np.zeros(n_steps) 
for k in range (100): # Numero de repeticiones de las repeticiones del experimento de caminata aleatoria ya realizado
    ks.append(k)
    promedios=[]
    promediototal=0   
    for j in range (100): # Numero de repeticiones del experimento de caminata aleatoria
        promedio=0 
        for i in range(n_steps-1): #experimentos de n_steps pasos
            walk_x[i+1] = walk_x[i] + random.choice((-1,1))
            promedio=sum(walk_x)/n_steps
        promedios.append(promedio)
        promediototal+=promedio
    des=np.std(promedios) #Desviacion Standart de los promedios
    promediototal=float(promediototal)/100
    t=(abs(promediototal)-n_steps*0.5)/des #el valor medio de la distancia para una caminata aleatoria es n_steps*p
    p=stats.t.sf(np.abs(t), 1)*2 #p-value para el problema de caminata aleatoria
    ps.append(p)


scatter(ks,ps)

# %%
n_steps = 200 # numero de pasos
ks=[]
ps=[]
p=[]
walk_x = np.zeros(n_steps) 
for k in range (100): # Numero de repeticiones de las repeticiones del experimento de caminata aleatoria ya realizado
    ks.append(k)
    promedios=[]
    promediototal=0   
    for j in range (100): # Numero de repeticiones del experimento de caminata aleatoria
        promedio=0 
        for i in range(n_steps-1): #experimentos de n_steps pasos
            walk_x[i+1] = walk_x[i] + random.choice((-1,1))
            promedio=sum(walk_x)/n_steps
        promedios.append(promedio)
        promediototal+=promedio
    des=np.std(promedios) #Desviacion Standart de los promedios
    promediototal=float(promediototal)/100
    t=(abs(promediototal)-n_steps*0.5)/des #el valor medio de la distancia para una caminata aleatoria es n_steps*p
    p=stats.t.sf(np.abs(t), 1)*2 #p-value para el problema de caminata aleatoria
    ps.append(p)


scatter(ks,ps)

# %%
n_steps = 500 # numero de pasos
ks=[]
ps=[]
p=[]
walk_x = np.zeros(n_steps) 
for k in range (100): # Numero de repeticiones de las repeticiones del experimento de caminata aleatoria ya realizado
    ks.append(k)
    promedios=[]
    promediototal=0   
    for j in range (100): # Numero de repeticiones del experimento de caminata aleatoria
        promedio=0 
        for i in range(n_steps-1): #experimentos de n_steps pasos
            walk_x[i+1] = walk_x[i] + random.choice((-1,1))
            promedio=sum(walk_x)/n_steps
        promedios.append(promedio)
        promediototal+=promedio
    des=np.std(promedios) #Desviacion Standart de los promedios
    promediototal=float(promediototal)/100
    t=(abs(promediototal)-n_steps*0.5)/des #el valor medio de la distancia para una caminata aleatoria es n_steps*p
    p=stats.t.sf(np.abs(t), 1)*2 #p-value para el problema de caminata aleatoria
    ps.append(p)


scatter(ks,ps)

# %%
n_steps = 1000 # numero de pasos
ks=[]
ps=[]
p=[]
walk_x = np.zeros(n_steps) 
for k in range (100): # Numero de repeticiones de las repeticiones del experimento de caminata aleatoria ya realizado
    ks.append(k)
    promedios=[]
    promediototal=0   
    for j in range (100): # Numero de repeticiones del experimento de caminata aleatoria
        promedio=0 
        for i in range(n_steps-1): #experimentos de n_steps pasos
            walk_x[i+1] = walk_x[i] + random.choice((-1,1))
            promedio=sum(walk_x)/n_steps
        promedios.append(promedio)
        promediototal+=promedio
    des=np.std(promedios) #Desviacion Standart de los promedios
    promediototal=float(promediototal)/100
    t=(abs(promediototal)-n_steps*0.5)/des #el valor medio de la distancia para una caminata aleatoria es n_steps*p
    p=stats.t.sf(np.abs(t), 1)*2 #p-value para el problema de caminata aleatoria
    ps.append(p)


scatter(ks,ps)

# %% [markdown]
# # Se observa que a mayor numero de pasos (n_steps) en la caminata aleatoria, la hipotesis permite inferir que el p value es menor. Por otra parte el valor optimo se cumple cuando el caminante de alrededor de 200 pasos, en dicho valor el p_value oscila en 0.05
